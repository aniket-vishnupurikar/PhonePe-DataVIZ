# %%
import pymysql
import pandas as pd
import mysql.connector
import pandas as pd

# %%
mydb = mysql.connector.connect(host="localhost", user="root", password="mysql")
mycursor = mydb.cursor(buffered=True)

# %%
mydb = mysql.connector.connect(host="localhost", user="root", password="mysql", database="phonepe")
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute(f'''CREATE TABLE Data_Aggregated_Transaction_Summary_Table
                   (Data_From BIGINT, Data_To BIGINT, Quarter INTEGER, State TEXT, Year INTEGER)''')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28700\866879746.py in <module>
#       1 mycursor.execute(f'''CREATE TABLE Data_Aggregated_Transaction_Summary_Table
# ----> 2                    (Data_From BIGINT, Data_To BIGINT, Quarter INTEGER, State TEXT, Year INTEGER)''')
#
# ~\AppData\Roaming\Python\Python37\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     613
#     614         try:
# --> 615             self._handle_result(self._connection.cmd_query(stmt))
#     616         except InterfaceError as err:
#     617             if self._connection.have_next_result:
#
# ~\AppData\Roaming\Python\Python37\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#    1044         query = bytes(packet)
#    1045         try:
# ...

# %% [markdown]
# # Pushing downloaded tables to database

# %% [markdown]
# ## Data_Aggregated_Transaction_Summary_Table.csv

# %%
df = pd.read_csv("Data_Aggregated_Transaction_Summary_Table.csv")

# %%
df
# Out:
#         Data From       Data To  Quarter                      State  Year
# 0    1.514745e+12  1.522175e+12        1  andaman-&-nicobar-islands  2018
# 1    1.522521e+12  1.530124e+12        2  andaman-&-nicobar-islands  2018
# 2    1.530383e+12  1.538073e+12        3  andaman-&-nicobar-islands  2018
# 3    1.538332e+12  1.545935e+12        4  andaman-&-nicobar-islands  2018
# 4    1.546281e+12  1.553711e+12        1  andaman-&-nicobar-islands  2019
# ..            ...           ...      ...                        ...   ...
# 715  1.633027e+12  1.640630e+12        4                west-bengal  2021
# 716  1.640975e+12  1.648406e+12        1                west-bengal  2022
# 717  1.648751e+12  1.656355e+12        2                west-bengal  2022
# 718  1.656614e+12  1.664303e+12        3                west-bengal  2022
# 719  1.664563e+12  1.672166e+12        4                west-bengal  2022
#
# [720 rows x 5 columns]

# %%
Data_Aggregated_Transaction_Summary_Table_cols = df.columns

# %%
# Out:
# Index(['Data From', 'Data To', 'Quarter', 'State', 'Year'], dtype='object')

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Aggregated_Transaction_Summary_Table VALUES (%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_Transaction_Summary_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#                  0              1  2                          3     4
# 0    1514745000000  1522175400000  1  andaman-&-nicobar-islands  2018
# 1    1522521000000  1530124200000  2  andaman-&-nicobar-islands  2018
# 2    1530383400000  1538073000000  3  andaman-&-nicobar-islands  2018
# 3    1538332200000  1545935400000  4  andaman-&-nicobar-islands  2018
# 4    1546281000000  1553711400000  1  andaman-&-nicobar-islands  2019
# ..             ...            ... ..                        ...   ...
# 715  1633026600000  1640629800000  4                west-bengal  2021
# 716  1640975400000  1648405800000  1                west-bengal  2022
# 717  1648751400000  1656354600000  2                west-bengal  2022
# 718  1656613800000  1664303400000  3                west-bengal  2022
# 719  1664562600000  1672165800000  4                west-bengal  2022
#
# [720 rows x 5 columns]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       720 non-null    int64
#  1   1       720 non-null    int64
#  2   2       720 non-null    int64
#  3   3       720 non-null    object
#  4   4       720 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 28.2+ KB

# %% [markdown]
# ## Data_Aggregated_Transaction_Table.csv

# %%
df = pd.read_csv("Data_Aggregated_Transaction_Table.csv")
df
# Out:
#                   Payment Mode  Quarter                      State  \
# 0     Recharge & bill payments        1  andaman-&-nicobar-islands
# 1        Peer-to-peer payments        1  andaman-&-nicobar-islands
# 2            Merchant payments        1  andaman-&-nicobar-islands
# 3           Financial Services        1  andaman-&-nicobar-islands
# 4                       Others        1  andaman-&-nicobar-islands
# ...                        ...      ...                        ...
# 3589     Peer-to-peer payments        4                west-bengal
# 3590         Merchant payments        4                west-bengal
# 3591  Recharge & bill payments        4                west-bengal
# 3592        Financial Services        4                west-bengal
# 3593                    Others        4                west-bengal
#
#       Total Amount  Total Transactions count  Year
# 0     1.845307e+06                    4200.0  2018
# 1     1.213866e+07                    1871.0  2018
# ...

# %%
Data_Aggregated_Transaction_Table_cols = df.columns

# %%
mycursor.execute(f'''CREATE TABLE Data_Aggregated_Transaction_Table
                   (Payment_Mode TEXT, Quarter INTEGER, State TEXT, Total_Amount BIGINT, Total_Transaction_Count BIGINT,
                   Year INTEGER)''')

# %%
mycursor.execute(f'''DROP TABLE Data_Aggregated_Transaction_Table''')
mydb.commit()

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Aggregated_Transaction_Table VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_Transaction_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#                              0  1                          2             3  \
# 0     Recharge & bill payments  1  andaman-&-nicobar-islands       1845307
# 1        Peer-to-peer payments  1  andaman-&-nicobar-islands      12138655
# 2            Merchant payments  1  andaman-&-nicobar-islands        452507
# 3           Financial Services  1  andaman-&-nicobar-islands         10601
# 4                       Others  1  andaman-&-nicobar-islands        184690
# ...                        ... ..                        ...           ...
# 3589     Peer-to-peer payments  4                west-bengal  620222191588
# 3590         Merchant payments  4                west-bengal  140807748126
# 3591  Recharge & bill payments  4                west-bengal   26026633153
# 3592        Financial Services  4                west-bengal     261122865
# 3593                    Others  4                west-bengal     457937875
#
#               4     5
# 0          4200  2018
# ...

# %% [markdown]
# ## Data_Aggregated_User_Summary_Table.csv

# %%
df = pd.read_csv("Data_Aggregated_User_Summary_Table.csv")
df
# Out:
#      AppOpenings  Quarter  Registered Users                      State  Year
# 0            0.0        1            6740.0  andaman-&-nicobar-islands  2018
# 1            0.0        2            9405.0  andaman-&-nicobar-islands  2018
# 2            0.0        3           12149.0  andaman-&-nicobar-islands  2018
# 3            0.0        4           15222.0  andaman-&-nicobar-islands  2018
# 4            0.0        1           18596.0  andaman-&-nicobar-islands  2019
# ..           ...      ...               ...                        ...   ...
# 715  512335839.0        4        20644527.0                west-bengal  2021
# 716  236131065.0        1        21919787.0                west-bengal  2022
# 717  250276369.0        2        23124388.0                west-bengal  2022
# 718  256445748.0        3        24372048.0                west-bengal  2022
# 719  678066327.0        4        25536381.0                west-bengal  2022
#
# [720 rows x 5 columns]

# %%
Data_Aggregated_User_Summary_Table_cols = df.columns

# %%
Data_Aggregated_User_Summary_Table_cols
# Out:
# Index(['AppOpenings', 'Quarter', 'Registered Users', 'State', 'Year'], dtype='object')

# %%
mycursor.execute(f'''CREATE TABLE Data_Aggregated_User_Summary_Table
                   (AppOpenings BIGINT, Quarter INTEGER, Registered_Users BIGINT, State TEXT, Year INTEGER)''')

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Aggregated_User_Summary_Table VALUES (%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_User_Summary_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#              0  1         2                          3     4
# 0            0  1      6740  andaman-&-nicobar-islands  2018
# 1            0  2      9405  andaman-&-nicobar-islands  2018
# 2            0  3     12149  andaman-&-nicobar-islands  2018
# 3            0  4     15222  andaman-&-nicobar-islands  2018
# 4            0  1     18596  andaman-&-nicobar-islands  2019
# ..         ... ..       ...                        ...   ...
# 715  512335839  4  20644527                west-bengal  2021
# 716  236131065  1  21919787                west-bengal  2022
# 717  250276369  2  23124388                west-bengal  2022
# 718  256445748  3  24372048                west-bengal  2022
# 719  678066327  4  25536381                west-bengal  2022
#
# [720 rows x 5 columns]

# %% [markdown]
# ## Data_Aggregated_User_Table.csv

# %%
df = pd.read_csv("Data_Aggregated_User_Table.csv")
df
# Out:
#      Brand Name  Percentage Share of Brand  Quarter  Registered Users Count  \
# 0        Xiaomi                   0.247033        1                  1665.0
# 1       Samsung                   0.214392        1                  1445.0
# 2          Vivo                   0.145697        1                   982.0
# 3          Oppo                   0.074332        1                   501.0
# 4       OnePlus                   0.049258        1                   332.0
# ...         ...                        ...      ...                     ...
# 6727     Lenovo                   0.015056        1                330017.0
# 6728    Infinix                   0.012987        1                284678.0
# 6729       Asus                   0.012790        1                280347.0
# 6730      Apple                   0.012671        1                277752.0
# 6731     Others                   0.100199        1               2196334.0
#
#                           State  Year
# ...

# %%
Data_Aggregated_User_Table_cols = df.columns

# %%
mycursor.execute(f'''CREATE TABLE Data_Aggregated_User_Table
                   (Brand_Name TEXT, Percentage_Share_of_Brand FLOAT, Quarter INTEGER, Registered_Users_Count BIGINT, 
                   State TEXT, Year INTEGER)''')

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Aggregated_User_Table VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_User_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#             0         1  2        3                          4     5
# 0      Xiaomi  0.247033  1     1665  andaman-&-nicobar-islands  2018
# 1     Samsung  0.214392  1     1445  andaman-&-nicobar-islands  2018
# 2        Vivo  0.145697  1      982  andaman-&-nicobar-islands  2018
# 3        Oppo  0.074332  1      501  andaman-&-nicobar-islands  2018
# 4     OnePlus  0.049258  1      332  andaman-&-nicobar-islands  2018
# ...       ...       ... ..      ...                        ...   ...
# 6727   Lenovo  0.015056  1   330017                west-bengal  2022
# 6728  Infinix  0.012987  1   284678                west-bengal  2022
# 6729     Asus  0.012790  1   280347                west-bengal  2022
# 6730    Apple  0.012671  1   277752                west-bengal  2022
# 6731   Others  0.100199  1  2196334                west-bengal  2022
#
# [6732 rows x 6 columns]

# %% [markdown]
# ## Data_Map_Transaction_Table.csv

# %%
df = pd.read_csv("Data_Map_Transaction_Table.csv")
df
# Out:
#                               Place Name  Quarter                      State  \
# 0      north and middle andaman district        1  andaman-&-nicobar-islands
# 1                 south andaman district        1  andaman-&-nicobar-islands
# 2                      nicobars district        1  andaman-&-nicobar-islands
# 3      north and middle andaman district        2  andaman-&-nicobar-islands
# 4                 south andaman district        2  andaman-&-nicobar-islands
# ...                                  ...      ...                        ...
# 14631                     nadia district        4                west-bengal
# 14632                   birbhum district        4                west-bengal
# 14633           purba medinipur district        4                west-bengal
# 14634                    maldah district        4                west-bengal
# 14635                 darjiling district        4                west-bengal
#
# ...

# %%
Data_Map_Transaction_Table_cols = df.columns

# %%
Data_Map_Transaction_Table_cols
# Out:
# Index(['Place Name', 'Quarter', 'State', 'Total Amount',
#        'Total Transactions count', 'Year'],
#       dtype='object')

# %%
mycursor.execute(f'''CREATE TABLE Data_Map_Transaction_Table
                   (Place_Name TEXT, Quarter INTEGER, State TEXT, Total_Amount BIGINT, Total_Transactions_Count BIGINT,
                   Year INTEGER)''')

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Map_Transaction_Table VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Map_Transaction_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#                                        0  1                          2  \
# 0      north and middle andaman district  1  andaman-&-nicobar-islands
# 1                 south andaman district  1  andaman-&-nicobar-islands
# 2                      nicobars district  1  andaman-&-nicobar-islands
# 3      north and middle andaman district  2  andaman-&-nicobar-islands
# 4                 south andaman district  2  andaman-&-nicobar-islands
# ...                                  ... ..                        ...
# 14631                     nadia district  4                west-bengal
# 14632                   birbhum district  4                west-bengal
# 14633           purba medinipur district  4                west-bengal
# 14634                    maldah district  4                west-bengal
# 14635                 darjiling district  4                west-bengal
#
#                  3         4     5
# 0           931663       442  2018
# 1         12560249      5688  2018
# ...

# %% [markdown]
# ## Data_Map_User_Table.csv

# %%
df = pd.read_csv("Data_Map_User_Table.csv")
df
# Out:
#        App Openings                         Place Name  Quarter  \
# 0               0.0  north and middle andaman district        1
# 1               0.0             south andaman district        1
# 2               0.0                  nicobars district        1
# 3               0.0  north and middle andaman district        2
# 4               0.0             south andaman district        2
# ...             ...                                ...      ...
# 14635    33853990.0                     nadia district        4
# 14636    20950662.0                   birbhum district        4
# 14637    38278506.0           purba medinipur district        4
# 14638    29023743.0                    maldah district        4
# 14639    15982631.0                 darjiling district        4
#
#        Registered Users Count                      State  Year
# 0                       632.0  andaman-&-nicobar-islands  2018
# 1                      5846.0  andaman-&-nicobar-islands  2018
# ...

# %%
Data_Map_User_Table_cols = df.columns

# %%
Data_Map_User_Table_cols
# Out:
# Index(['App Openings', 'Place Name', 'Quarter', 'Registered Users Count',
#        'State', 'Year'],
#       dtype='object')

# %%
mycursor.execute(f'''CREATE TABLE Data_Map_User_Table
                   (App_Openings BIGINT, Place_Name Text, Quarter INTEGER, Registered_Users_Count BIGINT, State TEXT,
                   Year INTEGER)''')

# %%
for i,row in df.iterrows():
    #here %S means string values 
    sql = "INSERT INTO Data_Map_User_Table VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    print("Record inserted")
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()
    
# except Error as e:
#     print("Error while connecting to MySQL", e)
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
mycursor.execute('SELECT * FROM Data_Map_User_Table')
table_rows = mycursor.fetchall()
dff = pd.DataFrame(table_rows)

# %%
dff
# Out:
#               0                                  1  2        3  \
# 0             0  north and middle andaman district  1      632
# 1             0             south andaman district  1     5846
# 2             0                  nicobars district  1      262
# 3             0  north and middle andaman district  2      911
# 4             0             south andaman district  2     8143
# ...         ...                                ... ..      ...
# 14635  33853990                     nadia district  4  1359420
# 14636  20950662                   birbhum district  4   855236
# 14637  38278506           purba medinipur district  4  1346908
# 14638  29023743                    maldah district  4   954892
# 14639  15982631                 darjiling district  4   564562
#
#                                4     5
# 0      andaman-&-nicobar-islands  2018
# 1      andaman-&-nicobar-islands  2018
# 2      andaman-&-nicobar-islands  2018
# 3      andaman-&-nicobar-islands  2018
# ...

# %%
print(Data_Aggregated_Transaction_Summary_Table_cols)
print(Data_Aggregated_Transaction_Table_cols)
print(Data_Aggregated_User_Summary_Table_cols)
print(Data_Aggregated_User_Table_cols)
print(Data_Map_Transaction_Table_cols)
print(Data_Map_User_Table_cols)
# Out:
# Index(['Data From', 'Data To', 'Quarter', 'State', 'Year'], dtype='object')
# Index(['Payment Mode', 'Quarter', 'State', 'Total Amount',
#        'Total Transactions count', 'Year'],
#       dtype='object')
# Index(['AppOpenings', 'Quarter', 'Registered Users', 'State', 'Year'], dtype='object')
# Index(['Brand Name', 'Percentage Share of Brand', 'Quarter',
#        'Registered Users Count', 'State', 'Year'],
#       dtype='object')
# Index(['Place Name', 'Quarter', 'State', 'Total Amount',
#        'Total Transactions count', 'Year'],
#       dtype='object')
# Index(['App Openings', 'Place Name', 'Quarter', 'Registered Users Count',
#        'State', 'Year'],
#       dtype='object')

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_Transaction_Summary_Table')
table_rows = mycursor.fetchall()
Data_Aggregated_Transaction_Summary_Table = pd.DataFrame(table_rows)
Data_Aggregated_Transaction_Summary_Table.columns = ['Data From', 'Data To', 'Quarter', 'State', 'Year']

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_Transaction_Table')
table_rows = mycursor.fetchall()
Data_Aggregated_Transaction_Table = pd.DataFrame(table_rows)
Data_Aggregated_Transaction_Table.columns = ['Payment Mode', 'Quarter', 'State', 'Total Amount',
       'Total Transactions count', 'Year']

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_User_Summary_Table')
table_rows = mycursor.fetchall()
Data_Aggregated_User_Summary_Table = pd.DataFrame(table_rows)
Data_Aggregated_User_Summary_Table.columns = ['AppOpenings', 'Quarter', 'Registered Users', 'State', 'Year']

# %%
mycursor.execute('SELECT * FROM Data_Aggregated_User_Table')
table_rows = mycursor.fetchall()
Data_Aggregated_User_Table = pd.DataFrame(table_rows)
Data_Aggregated_User_Table.columns = ['Brand Name', 'Percentage Share of Brand', 'Quarter',
       'Registered Users Count', 'State', 'Year']

# %%
mycursor.execute('SELECT * FROM Data_Map_Transaction_Table')
table_rows = mycursor.fetchall()
Data_Map_Transaction_Table = pd.DataFrame(table_rows)
Data_Map_Transaction_Table.columns = ['Place Name', 'Quarter', 'State', 'Total Amount',
       'Total Transactions count', 'Year']

# %%
mycursor.execute('SELECT * FROM Data_Map_User_Table')
table_rows = mycursor.fetchall()
Data_Map_User_Table = pd.DataFrame(table_rows)
Data_Map_User_Table.columns = ['App Openings', 'Place Name', 'Quarter', 'Registered Users Count',
       'State', 'Year']
